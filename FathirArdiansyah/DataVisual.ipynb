# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bulan = ['Januari', 'Februaru', 'Maret', 'April', 'Mei', 'Juni', 'Juli', 'Agustus', 'September', 'Oktober', 'November', 'Desember']

#Pengeluaran antara 500.000 - 2.000.000

minggu1 = np.random.randint(500000,2000001,12)
minggu2 = np.random.randint(500000,2000001,12)
minggu3 = np.random.randint(500000,2000001,12)
minggu4 = np.random.randint(500000,2000001,12)

data = {
    'Bulan' : bulan,
    'minggu1' : minggu1,
    'minggu2' : minggu2,
    'minggu3' : minggu3,
    'minggu4' : minggu4
}

df = pd.DataFrame(data)

df['Total Pengeluaran'] = df[['minggu1', 'minggu2', 'minggu3', 'minggu4']].sum(axis=1)
df
# Out:
#         Bulan  minggu1  minggu2  minggu3  minggu4  Total Pengeluaran
# 0     Januari   665269  1466873  1739247  1275337            5146726
# 1    Februaru  1803739   873878  1323650  1459014            5460281
# 2       Maret  1948511   649050  1613822  1016426            5227809
# 3       April   522877   925595  1773547   625330            3847349
# 4         Mei   518569  1255588  1076018  1369499            4219674
# 5        Juni  1546650  1734480  1897840  1014613            6193583
# 6        Juli  1356091  1920946  1166887   996682            5440606
# 7     Agustus   880632  1505155  1572746  1578784            5537317
# 8   September   945807   772210  1988939  1558161            5265117
# 9     Oktober  1895276  1807188  1184660  1471772            6358896
# 10   November   934598  1423730   741562  1113362            4213252
# 11   Desember   679682  1141625   527770  1744357            4093434

# %%
#Total pengelaran perbulan

plt.figure(figsize=(12,6)) #Canvas dengan ukuran Width, height (inch)
plt.title('Total pengeluaran per bulan')
plt.bar(df['Bulan'], df['Total Pengeluaran'], color='pink')
plt.xticks(rotation=45)
plt.ylabel("Rupiah")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#Scatter plot untuk analisa data pengeluaran per minggu dan per bulan
plt.figure(figsize=(12,6))
for minggu in ['minggu1','minggu2','minggu3','minggu4']:
    plt.plot(df['Bulan'], df[minggu], marker='o', label=minggu)

plt.title("Pengeluaran Per Minggu")
plt.xlabel('Bulan')
plt.ylabel('Pengeluaran (Rupiah)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9,9))
plt.pie(df['Total Pengeluaran'], labels=df['Bulan'], startangle=90, autopct='%1.1f%%')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

df['Bulan_Angka'] = np.arange(1,13)

x = df[['Bulan_Angka']]
y = df['Total Pengeluaran']

model = LinearRegression()

model.fit(x,y)
prediksi = model.predict([[13]])[0]
print(f"Hasil Prediksi adalah: {prediksi}")
# Out:
# Hasil Prediksi adalah: 5072458.818181818
# C:\Users\ASUS VIVOBOOK GO14\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('bapenda-od_15833_jml_pajak_denda_kndrn_brmtr__jenis_pajak_kndrn_brm_v4_data.csv')
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3201
# 2      3             32    JAWA BARAT                 3202
# 3      4             32    JAWA BARAT                 3202
# 4      5             32    JAWA BARAT                 3202
# ..   ...            ...           ...                  ...
# 811  812             32    JAWA BARAT                 3277
# 812  813             32    JAWA BARAT                 3278
# 813  814             32    JAWA BARAT                 3278
# 814  815             32    JAWA BARAT                 3279
# 815  816             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota              cabang_pelayanan  jenis_pkb  \
# 0       KABUPATEN BOGOR    KABUPATEN BOGOR (CIBINONG)  PKB POKOK
# 1       KABUPATEN BOGOR    KABUPATEN BOGOR (CIBINONG)  PKB DENDA
# ...

# %% [markdown]
# <h1><marquee>Skenario Analisis Data</marquee></h1>
# <ol>
#     <li>Provinsi Jawa Barat sesuai ketentuan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data numerik.</li>
#     <li>Lingkup data berasal dari wilayah Provinsi Jawa Barat sesuai ketentuan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data teks.</li>
#     <li>Kode dari setiap kabupaten dan kota di Provinsi Jawa Barat sesuai ketentuan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data numerik.</li>
#     <li> lingkup data berasal dari setiap kabupaten dan kota di Provinsi Jawa Barat sesuai penamaan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data teks.</li>
#     <li>Pembagian wilayah cabang pelayanan samsat dengan tipe data teks.</li>
#     <li>Jenis pembayaran pajak kendaraan bermotor dengan tipe data teks</li>
#     <li>Jenis pembayaran pajak berupa denda/sanksi atas kendaraan bermotor.</li>
#     <li>Jenis pembayaran pajak berupa pokok atas kendaraan bermotor.</li>
#     <li>Jumlah pendapatan dari pajak dan denda kendaraan dengan tipe data numerik.</li>
#     <li>Satuan dari pengukuran jumlah pembayaran pajak dan denda dalam rupiah dengan tipe data teks.</li>
#     <li>Tahun produksi data dengan tipe data teks.</li>
# </ol>
